# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# - level 1
#     - level 2
#     - level 2
# - level 1

# %% [markdown]
# *단어, 단어*
# ### 테이블
# | 컬럼 1 | 걸럼 2 | 컬럼 3 |
# |--------|--------|--------|
# | 내용 1 | 내용 2 | 내용 3 |

# %% [markdown]
# ### 그림 같은거
# ![image.png](attachment:image.png)

# %%
a = 10 + 20

# %%
a
# Out:
# 30

# %% [markdown]
# 만약 노트북의 셀을 처음부터 순서대로 실행 순서를 맞추어야 할 경우
#
# Kernel / Restart & Run All 로 전체 실행 순서를 맞추어주는 것이 좋아
